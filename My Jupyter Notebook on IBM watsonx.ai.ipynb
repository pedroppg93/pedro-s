# %% [markdown]
# # My Jupyter Notebook on IBM watsonx.ai

# %% [markdown]
# **Pedro P. Paz** Data Scientist

# %% [markdown]
# *Data science interests me because it allows me to implement tools and examine subjects that normally would not be within my reach*

# %% [markdown]
# ***As you can see, in cell 5, a simple code operation is presented where 2+2 equals 4 as shown in output.***

# %%
2+2
# Out:
# 4

# %% [markdown]
# # Data Science Overview
#
# ## What is Data Science?
# Data science is an interdisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data.
#
# ## Key Components of Data Science
#
# ### Core Technologies (Bulleted List)
# - **Machine Learning**: Algorithms that learn from data
# - **Statistics**: Mathematical foundation for data analysis
# - **Data Visualization**: Graphical representation of information
# - **Big Data Technologies**: Tools like Hadoop and Spark
# - **Programming**: Python, R, SQL
#
# ### Data Science Process (Numbered List)
# 1. **Problem Definition**: Understand business objectives
# 2. **Data Collection**: Gather relevant data from various sources
# 3. **Data Cleaning**: Handle missing values and inconsistencies
# 4. **Exploratory Data Analysis**: Understand patterns and relationships
# 5. **Model Building**: Create predictive models
# 6. **Model Deployment**: Implement models in production
# 7. **Monitoring & Maintenance**: Ensure ongoing performance
#
# ## Popular Data Science Tools
#
# | Tool | Category | Primary Use Case |
# |------|----------|------------------|
# | Python | Programming | General-purpose data analysis |
# | Jupyter Notebooks | Development Environment | Interactive coding and documentation |
# | TensorFlow | Machine Learning | Deep learning applications |
# | Tableau | Visualization | Business intelligence dashboards |
# | Pandas | Data Manipulation | Data cleaning and analysis |
#
# ## Resources & Further Learning
# - [Kaggle](https://www.kaggle.com/) - Practice datasets and competitions
# - [Towards Data Science](https://towardsdatascience.com/) - Blog and tutorials
# - [Coursera Data Science Courses](https://www.coursera.org/browse/data-science)
#
# ![Data Science Life Cycle](https://analyticstraininghub.com/wp-content/uploads/2022/10/data-science-600x503.png)
# ![Pillars of Data Science](https://lh7-us.googleusercontent.com/DMbgv_Zk90K2AbSSAJcNujoJ7_9NPeb71EXWkybqfW-mLRnMx9OJo5sM5kA_-kG_2_ykHkZijLXauX88_NkgWBmaXjOlQ0bgDPcm1ZkQ-nx7UqLIxJaFgHcEFF-xISjFxDLyNFTxl-lPsRLtYRA5Fhc)
# ![Deconstruction of Data Science](https://miro.medium.com/v2/resize:fit:1400/0*HqJW8n3ZMkR_ascV.jpg)
